# %% [markdown]
# 【【蓝桥杯】Python速成 课时1：基础语法和竞赛快速入门】https://www.bilibili.com/video/BV1Zs9VYrEgg?vd_source=298465310cd98e6ceddf1afe7d72e7ec
#
# # 快读模板

# %%
import sys
input = lambda:sys.stdin.readline().strip()

# %% [markdown]
# # lambel表达式基础

# %%
# 获得中位数
get_mid = lambda nums: nums[len(nums) // 2]
print(get_mid([1, 4, 5, 3, 7, 9]))
# Out:
# 3
