# %%
# lambel表达式基础

# %%
# 获得中位数
get_mid = lambda nums: nums[len(nums) // 2]
print(get_mid([1, 4, 5, 3]))
# Out:
# 5

# %%
# 获得中位数
get_mid = lambda nums: nums[len(nums) // 2]
print(get_mid([1, 4, 5, 3, 7, 9]))
# Out:
# 3
