# %%
import pandas as pd

# %%
data1[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File a:\Anaconda3\envs\Study\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data1[1]
#
# ...

# %%
data1['c']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data1['c']
#
# NameError: name 'data1' is not defined

# %%
data1[2:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data1[2:4]
#
# NameError: name 'data1' is not defined

# %%
data1['a':'e']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data1['a':'e']
#
# File a:\Anaconda3\envs\Study\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 # Do we have a slicer (on rows)?
#    4089 if isinstance(key, slice):
# -> 4090     return self._getitem_slice(key)
#    4092 # Do we have a (boolean) DataFrame?
#    4093 if isinstance(key, DataFrame):
#
# File a:\Anaconda3\envs\Study\Lib\site-packages\pandas\core\generic.py:4368, in NDFrame._getitem_slice(self, key)
#    4363 """
#    4364 __getitem__ for the case where the key is a slice object.
#    4365 """
#    4366 # _convert_slice_indexer to determine if this slice is positional
#    4367 #  or label based, and if the latter, convert to positional
# -> 4368 slobj = self.index._convert_slice_indexer(key, kind="getitem")
# ...

# %%
df['b']

# %%
df[['b', 'd']]

# %%
df[:2]

# %%
df[:2]['b', 'd']

# %%
df.iloc[:,:2]
