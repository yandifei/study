# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])

# %%
a.dtype.name
# Out:
# 'int64'

# %%
arr = np.array(['pandas', 'numpy', 'tensorflow', 'scipy'])
arr
# Out:
# array(['pandas', 'numpy', 'tensorflow', 'scipy'], dtype='<U10')

# %%
b = np.array([[1,2,3],[4,5,6]])
b
b.dtype
# Out:
# dtype('int64')

# %%
# 将数组 b 的数据类型转换为 float64（双精度浮点数），并将结果赋值给新变量 new_b
new_b = b.astype('float64')
print(new_b.dtype)
b.dtype
# Out:
# float64
# dtype('int64')

# %%
a = np.array([[1,2,3],[4,5,6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = np.array([[7,8,9],[10,11,12]])
b
# Out:
# array([[ 7,  8,  9],
#        [10, 11, 12]])

# %%
a * b
# Out:
# array([[ 7, 16, 27],
#        [40, 55, 72]])

# %%
c = np.array([3,4,5])

# %%
a * c
# Out:
# array([[ 3,  8, 15],
#        [12, 20, 30]])

# %%
print(a.shape)
print(c.shape)
# Out:
# (2, 3)
# (3,)

# %%
d = 20
a * d
# Out:
# array([[ 20,  40,  60],
#        [ 80, 100, 120]])
