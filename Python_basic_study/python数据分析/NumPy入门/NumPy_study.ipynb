# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.array([[1,2,3],[4,5,6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
print(a.shape)
print(b.shape)
# Out:
# (5,)
# (2, 3)

# %%
print(a.size)
print(b.size)
# Out:
# 5
# 6

# %%
print(a.dtype)
print(b.dtype)
# Out:
# int64
# int64

# %% [markdown]
# - 默认情况下，如果数组中都是整型那么dtype就是int64，但是如果数组里面有浮点数或者指定了dtpye是float那么数据会议浮点数存储

# %%
c = np.array([1,2,3,4,5],dtype=float)
c.dtype
# Out:
# dtype('float64')

# %%
d = np.array([1.0,2,3,4,5])
d.dtype
# Out:
# dtype('float64')
