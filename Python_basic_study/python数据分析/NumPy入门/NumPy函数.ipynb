# %%
import numpy as np

# %%
np.abs(-1.1)
# Out:
# np.float64(1.1)

# %%
# 平方根计算(计算数，计算的的开平方)
np.sqrt(2)
# Out:
# np.float64(1.4142135623730951)

# %%
# 平方计算(计算数，计算数的平方默认为2)
np.square(2)
# Out:
# np.int64(4)

# %%
# 计算自然常数 e 的 x 次方。
np.exp(2)
# Out:
# np.float64(7.38905609893065)

# %%
# 判断数字的符号（正数1、负数-1，0还是0）。
np.sign(-10)
# Out:
# np.int64(-1)

# %%
# 向上取整，计算大于或等于该数字的最小整数
np.ceil(1.1)
# Out:
# np.float64(2.0)

# %%
#  向下取整，计算小于或等于该数字的最大整数
np.floor(1.1)
# Out:
# np.float64(1.0)
